# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Amazon

# %%
d1= pd.read_csv("vivo_amazon.csv")

# %%
brand="Vivo"

# %%
d1.insert(loc=1,column="Brand",value=brand)

# %%
d1
# Out:
#     Unnamed: 0 Brand       Name             Colour  Storage  Battery  \
# 0            0  Vivo   vivo Y22       Starlit Blue    128.0   5000.0
# 1            1  Vivo  vivo Y15s        Mystic Blue     32.0   5000.0
# 2            2  Vivo   Vivo Y21      Midnight Blue     64.0   5000.0
# 3            3  Vivo  Vivo Y33T       Mirror Black    128.0   5000.0
# 4            4  Vivo   Vivo Y21       Diamond Glow     64.0   5000.0
# 5            5  Vivo   vivo Y16     Drizzling Gold     64.0   5000.0
# 6            6  Vivo   vivo Y35        Agate Black    128.0   5000.0
# 7            7  Vivo   Vivo Y75      Dancing Waves    128.0   4050.0
# 8            8  Vivo   vivo Y16      Stellar Black     64.0   5000.0
# 9            9  Vivo   vivo Y22    Metaverse Green    128.0   5000.0
# 10          10  Vivo  Vivo Y15s         Wave Green     32.0   5000.0
# 11          11  Vivo  vivo Y15C        Mystic Blue     64.0   5000.0
# 12          12  Vivo   Vivo Y01      Sapphire Blue     32.0   5000.0
# ...

# %%
d2=pd.read_csv("oneplus_amazon.csv")

# %%
d2
# Out:
#     Unnamed: 0                 Name            Colour  Storage  Battery  \
# 0            0      OnePlus Nord CE      Bahamas Blue    128.0   4500.0
# 1            1      OnePlus Nord 2T       Gray Shadow    128.0   4500.0
# 2            2      OnePlus Nord CE       Gray Mirror    128.0   4500.0
# 3            3      OnePlus Nord CE         Blue Tide    128.0   5000.0
# 4            4      OnePlus Nord 2T          Jade Fog    256.0   4500.0
# 5            5      OnePlus Nord 2T          Jade Fog    128.0   4500.0
# 6            6         OnePlus 10R       Forest Green    128.0   5000.0
# 7            7         OnePlus 10R       Forest Green    256.0   5000.0
# 8            8         OnePlus 10T    Moonstone Black    256.0   4800.0
# 9            9       OnePlus 10 Pro    Emerald Forest    128.0   5000.0
# 10          10         OnePlus 10R       Sierra Black    128.0   5000.0
# 11          11         OnePlus 10T    Moonstone Black    128.0   4800.0
# ...

# %%
brand="One Plus"
d2.insert(loc=1,column="Brand",value=brand)

# %%
d3=pd.read_csv("realme_amazon.csv")

# %%
d3
# Out:
#     Unnamed: 0              Name            Colour  Storage  Battery  \
# 0            0  realme narzo 50i        Mint Green     32.0   5000.0
# 1            1  realme narzo 50i        Mint Green     64.0   5000.0
# 2            2   realme narzo 50       Speed Black     64.0   5000.0
# 3            3   realme narzo 50       Speed Black    128.0   5000.0
# 4            4   realme Narzo 50       Hyper Black    128.0   5000.0
# 5            5  realme narzo 50A       Oxygen Blue    128.0   6000.0
# 6            6  realme narzo 50A        Flash Blue     64.0   5000.0
# 7            7  realme narzo 50A       Oxygen Blue     64.0   5000.0
# 8            8  realme narzo 50i         Dark Blue     32.0   5000.0
# 9            9   realme narzo 50        Speed Blue     64.0   5000.0
# 10          10        Realme C35     Glowing Green     64.0   5000.0
# 11          11  realme narzo 50i      Carbon Black     64.0   5000.0
# 12          12  realme narzo 50A        Flash Blue     64.0   5000.0
# ...

# %%
brand="Realme"
d3.insert(loc=1,column="Brand",value=brand)

# %%
d4=pd.read_csv("redmi_amazon.csv")

# %%
d4
# Out:
#     Unnamed: 0             Name              Colour  Storage  Battery  \
# 0            0   Redmi 11 Prime       Playful Green       64   5000.0
# 1            1   Redmi Note 11T         Matte Black      128   5000.0
# 2            2   Redmi 9A Sport        Carbon Black       32   5000.0
# 3            3   Redmi 9A Sport         Coral Green       32   5000.0
# 4            4    Redmi 9 Activ        Carbon Black       64   5000.0
# 5            5       Redmi 10A       Charcoal Black       64   5000.0
# 6            6        Redmi A1           Light Blue       32   5000.0
# 7            7   Redmi 10 Prime        Astral White       64   6000.0
# 8            8   Redmi Note 11T      Stardust White      128   5000.0
# 9            9        Redmi A1          Light Green       32   5000.0
# 10          10    Redmi Note 11        Horizon Blue       64   5000.0
# 11          11   Redmi Note 10S            Deep Sea       64   5000.0
# ...

# %%
brand="Redmi"
d4.insert(loc=1,column="Brand",value=brand)

# %%
d5=pd.read_csv("samsung_amazon.csv")

# %%
brand="Samsung"
d5.insert(loc=1,column="Brand",value=brand)

# %%
d5
# Out:
#     Unnamed: 0    Brand                Name          Colour  Storage  Battery  \
# 0            0  Samsung  Samsung Galaxy A23            Blue    128.0   5000.0
# 1            1  Samsung  Samsung Galaxy M32            Blue    128.0   6000.0
# 2            2  Samsung  Samsung Galaxy M32           Black    128.0   6000.0
# 3            3  Samsung  Samsung Galaxy M32            Blue     64.0   6000.0
# 4            4  Samsung  Samsung Galaxy M32           Black     64.0   6000.0
# 5            5  Samsung  Samsung Galaxy M33  Mystique Green    128.0   6000.0
# 6            6  Samsung  Samsung Galaxy M33   Emerald Brown    128.0   6000.0
# 7            7  Samsung  Samsung Galaxy M33      Ocean Blue    128.0   6000.0
# 8            8  Samsung  Samsung Galaxy M33  Mystique Green    128.0   6000.0
# 9            9  Samsung  Samsung Galaxy M53  Mystique Green    128.0   5000.0
# 10          10  Samsung  Samsung Galaxy M53      Ocean Blue    128.0   5000.0
# ...

# %%
d6=pd.read_csv("poco_amazon.csv")

# %%
brand="Poco"
d6.insert(loc=1,column="Brand",value=brand)

# %%
d6
# Out:
#    Unnamed: 0 Brand         Name       Colour  Storage  Battery  Camera_Pixel  \
# 0           0  Poco  POCO M4 Pro    Cool Blue     64.0   5000.0            64
# 1           1  Poco  POCO M4 Pro    Cool Blue     64.0   5000.0            64
# 2           2  Poco  POCO X4 Pro   Laser Blue    128.0   5000.0            64
# 3           3  Poco  POCO X4 Pro  Laser Black    128.0   5000.0            64
# 4           4  Poco     POCO C31   Royal Blue     64.0   5000.0            13
# 5           5  Poco     POCO C31  Shadow Gray     64.0   5000.0            13
# 6           6  Poco      POCO M5  Power Black    128.0   5000.0            50
#
#    Selfie_cam_pixel  Display_size  Technology  RAM Operating_system  \
# 0                16          16.3         4.0  6.0       Android 11
# 1                16          16.3         4.0  6.0       Android 11
# 2                16          16.9         5.0  6.0       Android 11
# 3                16          16.9         5.0  6.0       Android 11
# ...

# %%
d7=pd.read_csv("motorola_amazon.csv")

# %%
brand="Motorola"
d7.insert(loc=1,column="Brand",value=brand)

# %%
d7
# Out:
#     Unnamed: 0     Brand                 Name           Colour  Storage  \
# 0            0  Motorola        MOTOROLA e32s       Slate Gray     64.0
# 1            1  Motorola        MOTOROLA e32s     Misty Silver     64.0
# 2            2  Motorola        MOTOROLA e32s     Misty Silver     32.0
# 3            3  Motorola         MOTOROLA G60      Soft Silver    128.0
# 4            4  Motorola         MOTOROLA G60         Moonless    128.0
# 5            5  Motorola    MOTOROLA Moto g22     Iceberg Blue     64.0
# 6            6  Motorola         MOTOROLA g31   Meteorite Grey     64.0
# 7            7  Motorola         MOTOROLA g31   Meteorite Grey    128.0
# 8            8  Motorola             Moto E40      Carbon Gray      4.0
# 9            9  Motorola         Motorola g42   Atlantic Green      4.0
# 10          10  Motorola    MOTOROLA Moto g22     Cosmic Black      4.0
# 11          11  Motorola    Motorola E7 Power        Coral Red     64.0
# ...

# %%
d8=pd.read_csv("oppo_amazon.csv")

# %%
brand="Oppo"
d8.insert(loc=1,column="Brand",value=brand)

# %%
d8
# Out:
#     Unnamed: 0 Brand            Name            Colour  Storage  Battery  \
# 0            0  Oppo        OPPO A31     Mystery Black    128.0   4230.0
# 1            1  Oppo     OPPO A74 5G  Fantastic Purple    128.0   5000.0
# 2            2  Oppo     OPPO A74 5G       Fluid Black    128.0   5000.0
# 3            3  Oppo     OPPO K10 5G              Blue    128.0   5000.0
# 4            4  Oppo     OPPO K10 5G    Midnight Black    128.0   5000.0
# 5            5  Oppo       OPPO A15s       Fancy White    128.0   4230.0
# 6            6  Oppo       OPPO A15s     Dynamic Black    128.0   4230.0
# 7            7  Oppo       OPPO A15s       Fancy White     64.0   4230.0
# 8            8  Oppo       OPPO A15s    Rainbow Silver     64.0   4230.0
# 9            9  Oppo   OPPO F21s Pro    Dawnlight Gold    128.0   4500.0
# 10          10  Oppo    OPPO F21 Pro     Sunset Orange    128.0   4500.0
# 11          11  Oppo  OPPO Reno7 Pro              Blue    256.0   4500.0
# ...

# %%
f1=[d1,d2,d3,d4,d5,d6,d7,d8]

# %%
t1=pd.concat(f1)

# %%
t1
# Out:
#     Unnamed: 0 Brand          Name            Colour  Storage  Battery  \
# 0            0  Vivo      vivo Y22      Starlit Blue    128.0   5000.0
# 1            1  Vivo     vivo Y15s       Mystic Blue     32.0   5000.0
# 2            2  Vivo      Vivo Y21     Midnight Blue     64.0   5000.0
# 3            3  Vivo     Vivo Y33T      Mirror Black    128.0   5000.0
# 4            4  Vivo      Vivo Y21      Diamond Glow     64.0   5000.0
# ..         ...   ...           ...               ...      ...      ...
# 17          17  Oppo      Oppo A54             Black    128.0   5000.0
# 18          18  Oppo     OPPO A77s             Black    128.0   5000.0
# 19          19  Oppo     OPPO A77s            Orange    128.0   5000.0
# 20          20  Oppo  OPPO F19 Pro      Space Silver    128.0   4310.0
# 21          21  Oppo  OPPO F19 Pro  ['Space Silver']    128.0   4310.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  Technology  RAM  \
# ...

# %%
t1.to_csv("amazon_data.csv")

# %%
t1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## flipkart

# %%
a1=pd.read_csv("oppo_flipkart.csv")

# %%
brand="Oppo"
a1.insert(loc=1,column="Brand",value=brand)

# %%
a1
# Out:
#     Unnamed: 0 Brand        Name            Colour  Storage  Battery  \
# 0            0  Oppo    OPPO K10      Black Carbon    128.0   5000.0
# 1            1  Oppo    OPPO K10        Blue Flame    128.0   5000.0
# 2            2  Oppo    OPPO K10      Black Carbon    128.0   5000.0
# 3            3  Oppo    OPPO F19      Space Silver    128.0   4310.0
# 4            4  Oppo    OPPO F19     Midnight Blue    128.0   5000.0
# ..         ...   ...         ...               ...      ...      ...
# 85          85  Oppo     OPPO A9      Vanilla Mint    128.0   5000.0
# 86          86  Oppo    OPPO F15  Lightening Black    128.0   4000.0
# 87          87  Oppo    OPPO F15      Blazing Blue    128.0   4000.0
# 88          88  Oppo    OPPO F15     Unicorn White    128.0   4000.0
# 89          89  Oppo  OPPO Reno3    Midnight Black    256.0   4025.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  RAM  Star_ratings  \
# 0             50                16         16.74  6.0           4.4
# ...

# %%
a2=pd.read_csv("samsung_flipkart.csv")

# %%
brand="Samsung"
a2.insert(loc=1,column="Brand",value=brand)

# %%
a2
# Out:
#     Unnamed: 0    Brand            Name         Colour  Storage  Battery  \
# 0            0  Samsung  SAMSUNG Galaxy     Denim Blue     64.0   6000.0
# 1            1  Samsung  SAMSUNG Galaxy      Sea Green    512.0   6000.0
# 2            2  Samsung  SAMSUNG GALAXY  Midnight Blue    128.0   6000.0
# 3            3  Samsung  SAMSUNG Galaxy     Matte Aqua    128.0   5000.0
# 4            4  Samsung  SAMSUNG Galaxy     Deep Ocean    128.0   6000.0
# ..         ...      ...             ...            ...      ...      ...
# 76          76  Samsung  SAMSUNG Galaxy  Phantom Black    256.0   3700.0
# 77          77  Samsung  SAMSUNG Galaxy           Blue    128.0   5000.0
# 78          78  Samsung  SAMSUNG Galaxy          Peach     64.0   5000.0
# 79          79  Samsung     SAMSUNG M53  Emerald Brown    128.0   5000.0
# 80          80  Samsung  SAMSUNG Galaxy    Laser Green    128.0   7000.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  RAM  Star_ratings  \
# ...

# %%
a3=pd.read_csv("realme_flipkart.csv")

# %%
brand="Realme"
a3.insert(loc=1,column="Brand",value=brand)

# %%
a3
# Out:
#     Unnamed: 0   Brand          Name          Colour  Storage  Battery  \
# 0            0  Realme   realme C30s     Stripe Blue     32.0   5000.0
# 1            1  Realme    realme C35   Glowing Black    128.0   5000.0
# 2            2  Realme    realme C35   Glowing Green     64.0   5000.0
# 3            3  Realme     realme 9i   Rocking Black    128.0   5000.0
# 4            4  Realme  realme Narzo      Speed Blue    256.0   5000.0
# ..         ...     ...           ...             ...      ...      ...
# 77          77  Realme      realme 9    Aurora Green    128.0   4500.0
# 78          78  Realme     realme GT     Shade Black    128.0   5000.0
# 79          79  Realme     realme GT  Drifting White    128.0   5000.0
# 80          80  Realme     realme GT     Dash Yellow    256.0   5000.0
# 81          81  Realme     realme GT     Shade Black    256.0   5000.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  RAM  Star_ratings  \
# ...

# %%
a4=pd.read_csv("redmi_flipkart.csv")

# %%
brand="Redmi"
a4.insert(loc=1,column="Brand",value=brand)

# %%
a4
# Out:
#     Unnamed: 0  Brand        Name           Colour  Storage  Battery  \
# 0            0  Redmi    REDMI 9i    Metallic Blue    512.0   5000.0
# 1            1  Redmi    REDMI 10  Caribbean Green     64.0   6000.0
# 2            2  Redmi    REDMI 10     Pacific Blue     64.0   6000.0
# 3            3  Redmi    REDMI 10   Midnight Black     64.0   6000.0
# 4            4  Redmi    REDMI 9i      Coral Green    512.0   5000.0
# ..         ...    ...         ...              ...      ...      ...
# 75          75  Redmi    REDMI 10    Phantom Black     64.0   6000.0
# 76          76  Redmi  Redmi Note     Horizon Blue    128.0   5000.0
# 77          77  Redmi  Redmi Note  Starburst White     64.0   5000.0
# 78          78  Redmi  REDMI Note    Glacier White    128.0   5020.0
# 79          79  Redmi    REDMI 11      FlashyBlack    128.0   5000.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  RAM  Star_ratings  \
# 0             13                 5         16.59  4.0           4.3
# ...

# %%
a5=pd.read_csv("vivo_flipkart.csv")

# %%
brand="Vivo"
a5.insert(loc=1,column="Brand",value=brand)

# %%
a5
# Out:
#     Unnamed: 0 Brand      Name           Colour  Storage  Battery  \
# 0            0  Vivo   vivo T1  Starlight Black    128.0   5000.0
# 1            1  Vivo   vivo T1       Starry Sky    128.0   5000.0
# 2            2  Vivo   vivo T1  Midnight Galaxy    128.0   5000.0
# 3            3  Vivo   vivo T1  Rainbow Fantasy    128.0   5000.0
# 4            4  Vivo   vivo T1  Rainbow Fantasy    128.0   5000.0
# ..         ...   ...       ...              ...      ...      ...
# 89          89  Vivo  vivo V15       Topaz Blue    128.0   3700.0
# 90          90  Vivo  vivo X21            Black    128.0   3200.0
# 91          91  Vivo  vivo V21       Neon Spark    128.0   4000.0
# 92          92  Vivo   vivo S1     Skyline Blue     64.0   4500.0
# 93          93  Vivo  vivo U10    Electric Blue     64.0   5000.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  RAM  Star_ratings  \
# 0             50                16         16.71  6.0           4.4
# ...

# %%
a6=pd.read_csv("oneplus_flipkart.csv")

# %%
brand="One Plus"
a6.insert(loc=1,column="Brand",value=brand)

# %%
a6
# Out:
#     Unnamed: 0     Brand             Name             Colour  Storage  \
# 0            0  One Plus  OnePlus Nord CE          Blue Tide    128.0
# 1            1  One Plus  OnePlus Nord CE          Blue Tide    128.0
# 2            2  One Plus  OnePlus Nord CE         Black Dusk    128.0
# 3            3  One Plus  OnePlus Nord CE          Blue Tide    128.0
# 4            4  One Plus  OnePlus Nord 2T           Jade Fog    256.0
# ..         ...       ...              ...                ...      ...
# 74          74  One Plus    OnePlus 7 Pro        Mirror Grey    128.0
# 75          75  One Plus    OnePlus 7 Pro             Almond    256.0
# 76          76  One Plus        OnePlus 8  Interstellar Glow    256.0
# 77          77  One Plus        OnePlus 8      Glacial Green    128.0
# 78          78  One Plus    OnePlus 8 Pro      Glacial Green    128.0
#
#     Battery  Camera_Pixel  Selfie_cam_pixel  Display_size   RAM  Star_ratings  \
# ...

# %%
a7=pd.read_csv("motorola_flipkart.csv")

# %%
brand="Motorola"
a7.insert(loc=1,column="Brand",value=brand)

# %%
a7
# Out:
#     Unnamed: 0     Brand           Name              Colour  Storage  Battery  \
# 0            0  Motorola   MOTOROLA e40         Carbon Gray     64.0   5000.0
# 1            1  Motorola   MOTOROLA e40           Pink Clay     64.0   5000.0
# 2            2  Motorola   MOTOROLA g82     Meterorite Grey    128.0   5000.0
# 3            3  Motorola   MOTOROLA G62        Frosted Blue    128.0   5000.0
# 4            4  Motorola       Moto G71         Arctic Blue    128.0   5000.0
# ..         ...       ...            ...                 ...      ...      ...
# 77          77  Motorola  MOTOROLA Edge        Midnight Sky    128.0   4500.0
# 78          78  Motorola   MOTOROLA G10         Breeze Blue     64.0   6000.0
# 79          79  Motorola  MOTOROLA Edge  Interstellar Black    256.0   4610.0
# 80          80  Motorola        Moto X4       Sterling Blue     64.0   3000.0
# 81          81  Motorola   Motorola One        Ultra Violet    512.0   4000.0
#
# ...

# %%
a8=pd.read_csv("poco_flipkart.csv")

# %%
brand="Poco"
a8.insert(loc=1,column="Brand",value=brand)

# %%
a8
# Out:
#     Unnamed: 0 Brand     Name           Colour  Storage  Battery  \
# 0            0  Poco  POCO M4        Cool Blue    128.0   5000.0
# 1            1  Poco  POCO X4       Laser Blue    128.0   5000.0
# 2            2  Poco  POCO M4        Cool Blue    128.0   5000.0
# 3            3  Poco  POCO X4      Laser Black    128.0   5000.0
# 4            4  Poco  POCO M4           Yellow     64.0   5000.0
# ..         ...   ...      ...              ...      ...      ...
# 77          77  Poco  POCO X3      Cobalt Blue    512.0   6000.0
# 78          78  Poco  POCO X3       Steel Blue    128.0   5160.0
# 79          79  Poco  POCO M3        Cool Blue    512.0   6000.0
# 80          80  Poco  POCO F3   Predator Black    256.0   5065.0
# 81          81  Poco  POCO F3  Gunmetal Silver    256.0   5065.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  RAM  Star_ratings  \
# 0             50                16         16.76  6.0           4.2
# ...

# %%
f2=[a1,a2,a3,a4,a5,a6,a7,a8]

# %%
t2=pd.concat(f2)

# %%
t2
# Out:
#     Unnamed: 0 Brand      Name           Colour  Storage  Battery  \
# 0            0  Oppo  OPPO K10     Black Carbon    128.0   5000.0
# 1            1  Oppo  OPPO K10       Blue Flame    128.0   5000.0
# 2            2  Oppo  OPPO K10     Black Carbon    128.0   5000.0
# 3            3  Oppo  OPPO F19     Space Silver    128.0   4310.0
# 4            4  Oppo  OPPO F19    Midnight Blue    128.0   5000.0
# ..         ...   ...       ...              ...      ...      ...
# 77          77  Poco   POCO X3      Cobalt Blue    512.0   6000.0
# 78          78  Poco   POCO X3       Steel Blue    128.0   5160.0
# 79          79  Poco   POCO M3        Cool Blue    512.0   6000.0
# 80          80  Poco   POCO F3   Predator Black    256.0   5065.0
# 81          81  Poco   POCO F3  Gunmetal Silver    256.0   5065.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  RAM  Star_ratings  \
# 0             50                16         16.74  6.0           4.4
# ...

# %%
t2.duplicated().sum()
# Out:
# 0

# %%
t1
# Out:
#     Unnamed: 0 Brand          Name            Colour  Storage  Battery  \
# 0            0  Vivo      vivo Y22      Starlit Blue    128.0   5000.0
# 1            1  Vivo     vivo Y15s       Mystic Blue     32.0   5000.0
# 2            2  Vivo      Vivo Y21     Midnight Blue     64.0   5000.0
# 3            3  Vivo     Vivo Y33T      Mirror Black    128.0   5000.0
# 4            4  Vivo      Vivo Y21      Diamond Glow     64.0   5000.0
# ..         ...   ...           ...               ...      ...      ...
# 17          17  Oppo      Oppo A54             Black    128.0   5000.0
# 18          18  Oppo     OPPO A77s             Black    128.0   5000.0
# 19          19  Oppo     OPPO A77s            Orange    128.0   5000.0
# 20          20  Oppo  OPPO F19 Pro      Space Silver    128.0   4310.0
# 21          21  Oppo  OPPO F19 Pro  ['Space Silver']    128.0   4310.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  Technology  RAM  \
# ...

# %%
t1.drop(columns=["Technology","Operating_system"],inplace=True)

# %%
t1
# Out:
#     Unnamed: 0 Brand          Name            Colour  Storage  Battery  \
# 0            0  Vivo      vivo Y22      Starlit Blue    128.0   5000.0
# 1            1  Vivo     vivo Y15s       Mystic Blue     32.0   5000.0
# 2            2  Vivo      Vivo Y21     Midnight Blue     64.0   5000.0
# 3            3  Vivo     Vivo Y33T      Mirror Black    128.0   5000.0
# 4            4  Vivo      Vivo Y21      Diamond Glow     64.0   5000.0
# ..         ...   ...           ...               ...      ...      ...
# 17          17  Oppo      Oppo A54             Black    128.0   5000.0
# 18          18  Oppo     OPPO A77s             Black    128.0   5000.0
# 19          19  Oppo     OPPO A77s            Orange    128.0   5000.0
# 20          20  Oppo  OPPO F19 Pro      Space Silver    128.0   4310.0
# 21          21  Oppo  OPPO F19 Pro  ['Space Silver']    128.0   4310.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  RAM  Star_ratings  \
# ...

# %%
f3=[t1,t2]

# %%
df=pd.concat(f3)

# %%
df
# Out:
#     Unnamed: 0 Brand       Name           Colour  Storage  Battery  \
# 0            0  Vivo   vivo Y22     Starlit Blue    128.0   5000.0
# 1            1  Vivo  vivo Y15s      Mystic Blue     32.0   5000.0
# 2            2  Vivo   Vivo Y21    Midnight Blue     64.0   5000.0
# 3            3  Vivo  Vivo Y33T     Mirror Black    128.0   5000.0
# 4            4  Vivo   Vivo Y21     Diamond Glow     64.0   5000.0
# ..         ...   ...        ...              ...      ...      ...
# 77          77  Poco    POCO X3      Cobalt Blue    512.0   6000.0
# 78          78  Poco    POCO X3       Steel Blue    128.0   5160.0
# 79          79  Poco    POCO M3        Cool Blue    512.0   6000.0
# 80          80  Poco    POCO F3   Predator Black    256.0   5065.0
# 81          81  Poco    POCO F3  Gunmetal Silver    256.0   5065.0
#
#     Camera_Pixel  Selfie_cam_pixel  Display_size  RAM  Star_ratings  \
# 0             50                 8         16.63  6.0           3.6
# ...

# %%
df.to_csv("MobilePrice_data.csv")

# %%
t2.to_csv("flipkart_data.csv")
